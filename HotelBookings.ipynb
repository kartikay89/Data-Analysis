# %% [markdown]
# <a href="https://colab.research.google.com/github/kartikay89/Data-Analysis/blob/main/HotelBookings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Hotel Bookings**
#
# Source:
#
# 1. https://www.kaggle.com/jessemostipak/hotel-booking-demand
# 2. https://www.kaggle.com/shehanaaljaloud/bookingcom?select=booking.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

# %%
bookingData = pd.read_csv('/content/drive/MyDrive/Google Colab Data /booking.csv')
bookingData.head(10)
# Out:
#    Unnamed: 0                      city  ...            rate   review_numbers
# 0           0           Fatih, Istanbul  ...   Review score       55 reviews
# 1           1           Fatih, Istanbul  ...    Exceptional       15 reviews
# 2           2         Beyoglu, Istanbul  ...      Very Good       63 reviews
# 3           3         Beyoglu, Istanbul  ...        Awesome       26 reviews
# 4           4   European Side, Istanbul  ...      Excellent      216 reviews
# 5           5           Sisli, Istanbul  ...           Good       63 reviews
# 6           6           Sisli, Istanbul  ...      Excellent    3,150 reviews
# 7           7           Fatih, Istanbul  ...           Good      320 reviews
# 8           8         Beyoglu, Istanbul  ...        Awesome      341 reviews
# 9           9                  Istanbul  ...      Excellent      161 reviews
#
# [10 rows x 7 columns]

# %%
bookingData.columns
# Out:
# Index(['Unnamed: 0', 'city', 'distance', 'hotel_names', 'location', 'rate',
#        'review_numbers'],
#       dtype='object')

# %%
print(set(bookingData['city']))
print("Number of cities: ", len(set(bookingData['city'])))
print(set(bookingData['rate']))
print("Number of rating: ", len(set(bookingData['rate'])))
# print(set(bookingData['hotel_names']))
print("Number of hotels: : ", len(set(bookingData['hotel_names'])))
# Out:
# {' Chow Kit, Kuala Lumpur', ' Al Sufouh, Dubai', ' Sri Hartamas, Kuala Lumpur', ' Sisli, Istanbul', ' Dubai', ' Lambeth, London', ' Garhoud, Dubai', ' 1st arr., Paris', ' Mont Kiara, Kuala Lumpur', ' Asian Side, Istanbul', ' Upper West Side, New York', ' Barsha Heights (Tecom) , Dubai', ' Business Bay, Dubai', ' Bukit Merah, Singapore', ' Al Qusais, Dubai', ' SoHo, New York', ' Chinatown, New York', ' Deira, Dubai', ' Tribeca, New York', ' 12th arr., Paris', ' Midtown East, New York', ' Kuala Lumpur', ' Katong, Singapore', ' Shenton Way, Singapore', ' Downtown Singapore, Singapore', ' 20th arr., Paris', ' Uskudar, Istanbul', ' Dubai Internet City, Dubai', ' 15th arr., Paris', ' Kensington and Chelsea, London', ' Downtown Kuala Lumpur, Kuala Lumpur', ' 13th arr., Paris', ' 9th arr., Paris', ' Old Town Kaleici, Antalya', ' Islington, London', ' Palm Jumeirah, Dubai', ' Downtown Dubai, Dubai', ' Chinatown, Singapore', ' Pendik, Istanbul', ' Besiktas, Istanbul', ' Tower Hamlets, London',
# ...

# %%
# Let us take a look at booking demands and trends
hotelDemands = pd.read_csv('/content/drive/MyDrive/Google Colab Data /hotel_bookings.csv')
hotelDemands.head(10)
# Out:
#           hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0  Resort Hotel            0  ...           Check-Out               2015-07-01
# 1  Resort Hotel            0  ...           Check-Out               2015-07-01
# 2  Resort Hotel            0  ...           Check-Out               2015-07-02
# 3  Resort Hotel            0  ...           Check-Out               2015-07-02
# 4  Resort Hotel            0  ...           Check-Out               2015-07-03
# 5  Resort Hotel            0  ...           Check-Out               2015-07-03
# 6  Resort Hotel            0  ...           Check-Out               2015-07-03
# 7  Resort Hotel            0  ...           Check-Out               2015-07-03
# 8  Resort Hotel            1  ...            Canceled               2015-05-06
# 9  Resort Hotel            1  ...            Canceled               2015-04-22
#
# [10 rows x 32 columns]

# %%
print(set(hotelDemands['hotel']))
print(set(hotelDemands['arrival_date_year']))
print(set(hotelDemands['arrival_date_month']))
print(set(hotelDemands['hotel']))
print(set(hotelDemands['customer_type']))
print(set(hotelDemands['reservation_status']))
print(set(hotelDemands['deposit_type']))
print(set(hotelDemands['reserved_room_type']))
# Out:
# {'City Hotel', 'Resort Hotel'}
# {2016, 2017, 2015}
# {'June', 'January', 'December', 'March', 'July', 'October', 'August', 'February', 'September', 'November', 'April', 'May'}
# {'City Hotel', 'Resort Hotel'}
# {'Transient', 'Contract', 'Transient-Party', 'Group'}
# {'Check-Out', 'No-Show', 'Canceled'}
# {'No Deposit', 'Refundable', 'Non Refund'}
# {'L', 'P', 'A', 'F', 'B', 'D', 'H', 'C', 'G', 'E'}

# %%
filtered_rating_DF = bookingData[~bookingData.rate.str.contains("dubai")]
filtered_rating_DFV1 = filtered_rating_DF[~filtered_rating_DF.rate.str.contains("Review score")]

# %% [markdown]
# **Bar plot to see the type of ratings given by users**

# %%
#Rating bar chart

plt.subplots(figsize=(19,6))
sns.countplot('rate', data=filtered_rating_DFV1[1:] ,palette='RdYlGn_r',edgecolor=sns.color_palette('dark',7))
plt.xticks(rotation=90)
plt.ticklabel_format(style='plain', axis='y')
plt.title('Ratings given by users')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Looking at the city where hotels are most booked.**

# %%
#Cities bar chart

plt.subplots(figsize=(30,6))
sns.countplot('city', data=filtered_rating_DFV1[1:] ,palette='RdYlGn_r',edgecolor=sns.color_palette('dark',7))
plt.xticks(rotation=90)
plt.ticklabel_format(style='plain', axis='y')
plt.title('Cities')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
